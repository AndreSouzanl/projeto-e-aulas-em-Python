# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Trabalhando com numeros

# %%
print(24 + 10)
# Out:
# 34

# %%
qtde_pepsi= 130
preco_pepsi = 2.50
total_a_pagar = qtde_pepsi * preco_pepsi
print("O total a pagar é:", total_a_pagar)
# Out:
# O total a pagar é: 325.0
