# %% [markdown]
# # Meu primeiro programa Python
#
# Nesse programa vamos aprender a base inicial de Python

# %%
print("Meu primeiro código em Python!")
# Out:
# Meu primeiro código em Python!

# %%
print("Hello, World!")
print("Mais um código em Python.")
# Out:
# Hello, World!
# Mais um código em Python.
